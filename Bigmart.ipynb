# %% [markdown]
# # Importing Libraries

# %%
import numpy as np                #For mathematical calculations
import pandas as pd               #for working with data
import matplotlib.pyplot as plt   #For plotting graphs
import seaborn as sns             #For data visualization
import warnings                   #For ignoring warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("train_v9rqX0R.csv")
df2 = pd.read_csv("test_AbJTz2l.csv")
sample_dataset = pd.read_csv('sample_submission_8RXa3c6.csv')

# %%
df1.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df1.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df1.shape
# Out:
# (8523, 12)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df1.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# # Visualization

# %%
# histogram
df1.hist(figsize=(20,20))
plt.show()

# %%
# scatter plot matrix
pd.plotting.scatter_matrix(df1,figsize=(12,12))
plt.show()

# %%
sns.pairplot(df1)

# %% [markdown]
# # Handling Missing Values

# %%
#missing value
df1.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df1['Item_Weight'].value_counts()
# Out:
# Item_Weight
# 12.150    86
# 17.600    82
# 13.650    77
# 11.800    76
# 15.100    68
#           ..
# 7.275      2
# 7.685      1
# 9.420      1
# 6.520      1
# 5.400      1
# Name: count, Length: 415, dtype: int64

# %%
df1['Item_Weight'] = df1['Item_Weight'].fillna(df1['Item_Weight'].mean())
df2['Item_Weight'] = df2['Item_Weight'].fillna(df2['Item_Weight'].mean())

# %%
df1['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
df1['Outlet_Size'] = df1['Outlet_Size'].fillna(df1['Outlet_Size'].mode()[0])
df2['Outlet_Size'] = df2['Outlet_Size'].fillna(df2['Outlet_Size'].mode()[0])

# %%
df1.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#checking on the unique values of categorical data
print(df1['Item_Fat_Content'].unique())
print(df1['Item_Type'].unique())
print(df1['Outlet_Size'].unique())
print(df1['Outlet_Location_Type'].unique())
print(df1['Outlet_Type'].unique())
# Out:
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# ['Medium' 'High' 'Small']
# ['Tier 1' 'Tier 3' 'Tier 2']
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
df1['Item_Fat_Content'] = df1['Item_Fat_Content'].replace(['LF'], 'low fat')
df1['Item_Fat_Content'] = df1['Item_Fat_Content'].replace(['Low Fat'], 'low fat')
df1['Item_Fat_Content'] = df1['Item_Fat_Content'].replace(['reg'], 'Regular')

# %%
#checking on the unique values of categorical data
print(df2['Item_Fat_Content'].unique())
print(df2['Item_Type'].unique())
print(df2['Outlet_Size'].unique())
print(df2['Outlet_Location_Type'].unique())
print(df2['Outlet_Type'].unique())
# Out:
# ['Low Fat' 'reg' 'Regular' 'LF' 'low fat']
# ['Snack Foods' 'Dairy' 'Others' 'Fruits and Vegetables' 'Baking Goods'
#  'Health and Hygiene' 'Breads' 'Hard Drinks' 'Seafood' 'Soft Drinks'
#  'Household' 'Frozen Foods' 'Meat' 'Canned' 'Starchy Foods' 'Breakfast']
# ['Medium' 'Small' 'High']
# ['Tier 1' 'Tier 2' 'Tier 3']
# ['Supermarket Type1' 'Grocery Store' 'Supermarket Type3'
#  'Supermarket Type2']

# %%
df2['Item_Fat_Content'] = df2['Item_Fat_Content'].replace(['LF'], 'low fat')
df2['Item_Fat_Content'] = df2['Item_Fat_Content'].replace(['Low Fat'], 'low fat')
df2['Item_Fat_Content'] = df2['Item_Fat_Content'].replace(['reg'], 'Regular')

# %%
#looking at the new unique values
print(df1['Item_Fat_Content'].unique())
# Out:
# ['low fat' 'Regular']

# %%
#check on duplicate values
df1.duplicated().sum()
# Out:
# 0

# %%
df1.describe().T
# Out:
#                             count         mean          std       min  \
# Item_Weight                8523.0    12.857645     4.226124     4.555
# Item_Visibility            8523.0     0.066132     0.051598     0.000
# Item_MRP                   8523.0   140.992782    62.275067    31.290
# Outlet_Establishment_Year  8523.0  1997.831867     8.371760  1985.000
# Item_Outlet_Sales          8523.0  2181.288914  1706.499616    33.290
#
#                                    25%          50%          75%           max
# Item_Weight                   9.310000    12.857645    16.000000     21.350000
# Item_Visibility               0.026989     0.053931     0.094585      0.328391
# Item_MRP                     93.826500   143.012800   185.643700    266.888400
# Outlet_Establishment_Year  1987.000000  1999.000000  2004.000000   2009.000000
# Item_Outlet_Sales           834.247400  1794.331000  3101.296400  13086.964800

# %%
#visulalizing outliers by box plots in train data
df1.plot( kind='box',subplots=True,sharey=False,figsize=(10, 6))
plt.show()

# %%
#visulalizing outliers by box plots in test data
df2.plot( kind='box',subplots=True,sharey=False,figsize=(10, 6))
plt.show()

# %% [markdown]
# ## Handling Outliers

# %%
#function to replace outliers with the max value possible without missing the data in train data
def outliers(dataset,col):
  Q1 = dataset[col].quantile(0.25)
  Q3 = dataset[col].quantile(0.75)
  IQR = Q3-Q1
  lower_bound = Q1-1.5*IQR
  upper_bound = Q3+1.5*IQR

  for i in range(len(dataset)):
      if dataset[col].iloc[i] > upper_bound:
          dataset[col].iloc[i] = upper_bound
      if dataset[col].iloc[i] < lower_bound:
          dataset[col].iloc[i] = lower_bound
#replacing the outliers using the function 
outliers(df1,'Item_Visibility')
outliers(df1,'Item_Outlet_Sales')

# %%
#function to replace outliers with the max value possible without missing the data in test data
def outliers(dataset,col):
  Q1 = dataset[col].quantile(0.25)
  Q3 = dataset[col].quantile(0.75)
  IQR = Q3-Q1
  lower_bound = Q1-1.5*IQR
  upper_bound = Q3+1.5*IQR

  for i in range(len(dataset)):
      if dataset[col].iloc[i] > upper_bound:
          dataset[col].iloc[i] = upper_bound
      if dataset[col].iloc[i] < lower_bound:
          dataset[col].iloc[i] = lower_bound
#replacing the outliers using the function 
outliers(df2,'Item_Visibility')

# %%
#visulalizing box plots with removed outliers in train data
df1.plot( kind='box',subplots=True,sharey=False,figsize=(10, 6))
plt.show()

# %%
#visulalizing box plots with removed outliers in test data
df2.plot( kind='box',subplots=True,sharey=False,figsize=(10, 6))
plt.show()

# %%
#dropping unnecessarily columns
df1.drop(['Item_Identifier', 'Outlet_Identifier','Item_Weight'], axis=1, inplace = True)
df2.drop(['Item_Identifier', 'Outlet_Identifier','Item_Weight'], axis=1, inplace = True)

# %%
df1.dtypes
# Out:
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ## Encoding

# %%
#Encoding ordinal data
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df1['Item_Fat_Content']= label_encoder.fit_transform(df1['Item_Fat_Content'])
df1['Outlet_Size']= label_encoder.fit_transform(df1['Outlet_Size'])
df1['Outlet_Location_Type']= label_encoder.fit_transform(df1['Outlet_Location_Type'])

# %%
df1.dtypes
# Out:
# Item_Fat_Content               int32
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Outlet_Size                    int32
# Outlet_Location_Type           int32
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
var_col = ['Item_Type','Outlet_Type']
le1 = LabelEncoder()
for i in var_col:
    df1[i] = le1.fit_transform(df1[i])

# %%
df2.dtypes
# Out:
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
label_encoder = LabelEncoder()
df2['Item_Fat_Content']= label_encoder.fit_transform(df2['Item_Fat_Content'])
df2['Outlet_Size']= label_encoder.fit_transform(df2['Outlet_Size'])
df2['Outlet_Location_Type']= label_encoder.fit_transform(df2['Outlet_Location_Type'])

# %%
var_col1 = ['Item_Type','Outlet_Type']
le1 = LabelEncoder()
for i in var_col1:
    df2[i] = le1.fit_transform(df2[i])

# %%
req_cols = ['Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP','Outlet_Establishment_Year','Outlet_Type', 'Outlet_Size','Outlet_Location_Type']

# %%
X = df1[req_cols]
y = df1['Item_Outlet_Sales']

# %%
X.head()
# Out:
#    Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0                 1         0.016047          4  249.8092
# 1                 0         0.019278         14   48.2692
# 2                 1         0.016760         10  141.6180
# 3                 0         0.000000          6  182.0950
# 4                 1         0.000000          9   53.8614
#
#    Outlet_Establishment_Year  Outlet_Type  Outlet_Size  Outlet_Location_Type
# 0                       1999            1            1                     0
# 1                       2009            2            1                     2
# 2                       1999            1            1                     0
# 3                       1998            0            1                     2
# 4                       1987            1            0                     2

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()
X.loc[:,['Item_Type','Item_MRP','Outlet_Establishment_Year']]  = minmax.fit_transform(X[['Item_Type','Item_MRP','Outlet_Establishment_Year']])

# %%
X.head()
# Out:
#    Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0                 1         0.016047   0.266667  0.927507
# 1                 0         0.019278   0.933333  0.072068
# 2                 1         0.016760   0.666667  0.468288
# 3                 0         0.000000   0.400000  0.640093
# 4                 1         0.000000   0.600000  0.095805
#
#    Outlet_Establishment_Year  Outlet_Type  Outlet_Size  Outlet_Location_Type
# 0                   0.583333            1            1                     0
# 1                   1.000000            2            1                     2
# 2                   0.583333            1            1                     0
# 3                   0.541667            0            1                     2
# 4                   0.083333            1            0                     2

# %%
df2.dtypes
# Out:
# Item_Fat_Content               int32
# Item_Visibility              float64
# Item_Type                      int32
# Item_MRP                     float64
# Outlet_Establishment_Year      int64
# Outlet_Size                    int32
# Outlet_Location_Type           int32
# Outlet_Type                    int32
# dtype: object

# %%
df2.head()
# Out:
#    Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0                 1         0.007565         13  107.8622
# 1                 0         0.038428          4   87.3198
# 2                 1         0.099575         11  241.7538
# 3                 1         0.015388         13  155.0340
# 4                 0         0.118599          4  234.2300
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                       1999            1                     0            1
# 1                       2007            1                     1            1
# 2                       1998            1                     2            0
# 3                       2007            1                     1            1
# 4                       1985            1                     2            3

# %%
req_cols1 = ['Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP','Outlet_Establishment_Year','Outlet_Type', 'Outlet_Size','Outlet_Location_Type']

# %%
X1 = df2[req_cols1]

# %%
X1.loc[:,['Item_Type','Item_MRP','Outlet_Establishment_Year']]  = minmax.fit_transform(X1[['Item_Type','Item_MRP','Outlet_Establishment_Year']])

# %%
X1.head()
# Out:
#    Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0                 1         0.007565   0.866667  0.323413
# 1                 0         0.038428   0.266667  0.235849
# 2                 1         0.099575   0.733333  0.894140
# 3                 1         0.015388   0.866667  0.524488
# 4                 0         0.118599   0.266667  0.862069
#
#    Outlet_Establishment_Year  Outlet_Type  Outlet_Size  Outlet_Location_Type
# 0                   0.583333            1            1                     0
# 1                   0.916667            1            1                     1
# 2                   0.541667            0            1                     2
# 3                   0.916667            1            1                     1
# 4                   0.000000            3            1                     2

# %%
X.to_csv('processed_train_data.csv',index=False)
X1.to_csv('processed_test_data.csv',index=False)
pd.read_csv('processed_train_data.csv').head(10)
y= df1.pop('Item_Outlet_Sales')

# %%
pd.read_csv('processed_test_data.csv').head(10)
# Out:
#    Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0                 1         0.007565   0.866667  0.323413
# 1                 0         0.038428   0.266667  0.235849
# 2                 1         0.099575   0.733333  0.894140
# 3                 1         0.015388   0.866667  0.524488
# 4                 0         0.118599   0.266667  0.862069
# 5                 0         0.063817   0.400000  0.363000
# 6                 0         0.082602   0.000000  0.077210
# 7                 1         0.015782   0.000000  0.209163
# 8                 0         0.123365   0.866667  0.271756
# 9                 1         0.005698   0.000000  0.660288
#
#    Outlet_Establishment_Year  Outlet_Type  Outlet_Size  Outlet_Location_Type
# 0                   0.583333            1            1                     0
# 1                   0.916667            1            1                     1
# 2                   0.541667            0            1                     2
# ...

# %% [markdown]
# ## Building Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error,r2_score
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, test_size=0.2)

# %%
models = [LinearRegression(), DecisionTreeRegressor(), RandomForestRegressor(), XGBRegressor(),GradientBoostingRegressor()]

# %%
lr =LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 1080.2900838561793

# %%
for model in models:
    reg = model
    reg.fit(X_train, y_train)
    y_pred = reg.predict(X_test)
    print(f'{model} MSE: {np.sqrt(mean_squared_error(y_test, y_pred))}',f'{model} r2 score: {(r2_score(y_test, y_pred))}')
# Out:
# LinearRegression() MSE: 1080.2900838561793 LinearRegression() r2 score: 0.533932632511406
# DecisionTreeRegressor() MSE: 1382.2545216836245 DecisionTreeRegressor() r2 score: 0.23696588527089835
# RandomForestRegressor() MSE: 1012.954935790302 RandomForestRegressor() r2 score: 0.5902224451153313
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6231802138076505

# %%
#this is done to improve the perfomance of the model
param_grid = {'n_estimators': [100, 200, 300],
              'max_depth': [3, 4, 5] ,
              'min_samples_split': [2, 4, 6]}


gb = GradientBoostingRegressor()
grid_search = GridSearchCV(gb, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

print(grid_search.best_params_)

# %%
y_pred = grid_search.predict(X_test)
print(f'{model} MSE: {np.sqrt(mean_squared_error(y_test, y_pred))}')

# %%
sample_dataset

# %%
prediction=grid_search.predict(test_data)
big_mart_sales = pd.DataFrame({'Item_Identifier': sample_dataset.Item_Identifier,
                       'Outlet_Identifier': sample_dataset.Outlet_Identifier,
                       'Item_Outlet_Sales': prediction})

big_mart_sales['Item_Outlet_Sales'] = big_mart_sales['Item_Outlet_Sales'].abs()
big_mart_sales.to_csv('bigmart_submission.csv', index=False)
